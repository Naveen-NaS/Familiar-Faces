# %%
# !pip install pywavelets
# Out:
# Collecting pywavelets
#   Downloading pywavelets-1.6.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.22.4 in c:\users\naveen sharma\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pywavelets) (1.25.1)
# Downloading pywavelets-1.6.0-cp311-cp311-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB 653.6 kB/s eta 0:00:07
#    -- ------------------------------------- 0.2/4.3 MB 2.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.6/4.3 MB 4.1 MB/s eta 0:00:01
#    --------- ------------------------------ 1.0/4.3 MB 5.2 MB/s eta 0:00:01
#    ------------ --------------------------- 1.4/4.3 MB 5.8 MB/s eta 0:00:01
#    -------------- ------------------------- 1.5/4.3 MB 5.4 MB/s eta 0:00:01
#    -------------- ------------------------- 1.6/4.3 MB 5.2 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.3 MB 4.4 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.3 MB 4.0 MB/s eta 0:00:01
#    --------------- ------------------------ 1.7/4.3 MB 3.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.7/4.3 MB 3.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.8/4.3 MB 3.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.8/4.3 MB 2.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.8/4.3 MB 2.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.8/4.3 MB 2.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.9/4.3 MB 2.5 MB/s eta 0:00:01
#    ------------------ --------------------- 1.9/4.3 MB 2.4 MB/s eta 0:00:01
#    ------------------ --------------------- 2.0/4.3 MB 2.3 MB/s eta 0:00:01
#    ------------------ --------------------- 2.0/4.3 MB 2.2 MB/s eta 0:00:02
#    ------------------- -------------------- 2.1/4.3 MB 2.2 MB/s eta 0:00:01
#    -------------------- ------------------- 2.2/4.3 MB 2.1 MB/s eta 0:00:01
#    -------------------- ------------------- 2.2/4.3 MB 2.1 MB/s eta 0:00:01
#    -------------------- ------------------- 2.2/4.3 MB 2.1 MB/s eta 0:00:01
#    --------------------- ------------------ 2.3/4.3 MB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.4/4.3 MB 2.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.5/4.3 MB 2.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.5/4.3 MB 1.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.5/4.3 MB 1.9 MB/s eta 0:00:01
#    ------------------------ --------------- 2.6/4.3 MB 1.9 MB/s eta 0:00:01
#    ------------------------- -------------- 2.7/4.3 MB 1.9 MB/s eta 0:00:01
#    ------------------------- -------------- 2.7/4.3 MB 1.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.8/4.3 MB 1.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.8/4.3 MB 1.8 MB/s eta 0:00:01
#    -------------------------- ------------- 2.9/4.3 MB 1.8 MB/s eta 0:00:01
#    --------------------------- ------------ 2.9/4.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.0/4.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.1/4.3 MB 1.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.2/4.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------ --------- 3.3/4.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------ --------- 3.3/4.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------- -------- 3.3/4.3 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 3.4/4.3 MB 1.7 MB/s eta 0:00:01
#    -------------------------------- ------- 3.5/4.3 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.6/4.3 MB 1.7 MB/s eta 0:00:01
#    --------------------------------- ------ 3.6/4.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.6/4.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.7/4.3 MB 1.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.8/4.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.9/4.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.9/4.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 3.9/4.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 4.0/4.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 4.0/4.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 4.1/4.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 1.6 MB/s eta 0:00:00
# Installing collected packages: pywavelets
# Successfully installed pywavelets-1.6.0

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy as np
# ----> 2 import cv2
#       3 import matplotlib
#       4 from matplotlib import pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img = cv2.imread('./test_images/naveen1.jpg')
img.shape
# Out:
# (3264, 2448, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (3264, 2448)

# %%
gray
# Out:
# array([[133, 132, 129, ..., 232, 233, 234],
#        [134, 134, 128, ..., 232, 234, 235],
#        [156, 154, 141, ..., 232, 233, 234],
#        ...,
#        [114, 114, 113, ..., 167, 155, 157],
#        [121, 120, 117, ..., 175, 170, 170],
#        [119, 119, 116, ..., 175, 173, 169]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 493, 1039, 1370, 1370]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (493, 1039, 1370, 1370)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (1370, 1370, 3)

# %% [markdown]
# ## Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 import numpy as np
# ----> 2 import pywt
#       3 import cv2
#       5 def w2d(img, mode='haar', level=1):
#
# ModuleNotFoundError: No module named 'pywt'
